# %%
import numpy as np

# %%
x = np.random.rand(10,9)

# %%
np.sum(x,axis=1)[:,None]
# Out:
# array([[4.28011097],
#        [4.5653006 ],
#        [4.07745896],
#        [2.87980342],
#        [4.03403941],
#        [5.18114148],
#        [5.02245979],
#        [3.50915314],
#        [3.33871972],
#        [3.91602263]])

# %%
from necutil import plot_vswr_2

plot_vswr_2([list(zip(np.linspace(7.0,7.3,7), np.linspace(1.1,1.5,7))),
             list(zip(np.linspace(7.0,7.3,7), np.linspace(2.3,1.5,7)))],
             ['tag'])

# %%
list(zip(np.linspace(7.0,7.3,7), np.linspace(1.1,1.5,7)))
# Out:
# [(7.0, 1.1),
#  (7.05, 1.1666666666666667),
#  (7.1, 1.2333333333333334),
#  (7.15, 1.3),
#  (7.2, 1.3666666666666667),
#  (7.25, 1.4333333333333333),
#  (7.3, 1.5)]
